# %% [markdown]
# # 네이버의 웹 문서 API

# %%
import os
import sys
import urllib.request
import pandas as pd 
import json 
import re
client_id = "9DdQYYWtoOpgrw1YWAYZ"
client_secret = "dq175srVEK"

query = urllib.parse.quote(input('검색 질의: '))
idx = 0 #몇개를 받아오는지 셀 수 있는 인덱스 변수 설정
display = 100
start = 1 
end = 1000

#저장을 판다스에 저장해보자 
web_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start,end,display):
    

    url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
            + "&display="+ str(display) \
            + "&start="+ str(start_index)

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag,'',items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx +=1
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색 질의: 이유식
#                                              Title  \
# 0                                       이유식 - 나무위키
# 1                               이유식 전문의 프로필 | 지식iN
# 2                                   이유식 교육 ㅣ 강남차병원
# 3    아벤트 이유식마스터기 및 유아용 식기 | Philips Avent - 필립스코리아
# 4                        아기가 잘먹는 이유식은 따로 있다 - 교보문고
# ..                                             ...
# 195                                    이유식 - 버드펠리스
# 196                              이유식분유 - 침구청소기 더보기
# 197              투데코 필수 이유식 준비물 세트, 블루, 1세트 - 핫딜추천
# 198                                      이유식 1 페이지
# 199                                      이유식 1 페이지
#
#                                                   Link  \
# 0      https://namu.wiki/w/%EC%9D%B4%EC%9C%A0%EC%8B%9D
# 1    https://kin.naver.com/profile/index.nhn?u=Xp0h...
# 2    https://gangnam.chamc.co.kr/health/lecture/bab...
# 3    https://www.philips.co.kr/c-m-mo/food-makers-t...
# 4    http://www.kyobobook.co.kr/product/detailViewK...
# ...

# %% [markdown]
# # 네이버 지식IN 검색

# %%
import os
import sys
import urllib.request
import pandas as pd 
import json 
import re
import openpyxl 

write_book = openpyxl.Workbook()
write_sheet = write_book.active 
write_sheet.append(['인덱스','Title','Link','Description'])
write_sheet.column_dimensions['B'].width = 50
write_sheet.column_dimensions['C'].width = 70

client_id = "9DdQYYWtoOpgrw1YWAYZ"
client_secret = "dq175srVEK"

query = urllib.parse.quote(input('검색 질의: '))
idx = 0 #몇개를 받아오는지 셀 수 있는 인덱스 변수 설정
display = 100
start = 1 
end = 1000
sort = 'sim'

#저장을 판다스에 저장해보자 
kin_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start,end,display):
    

    url = "https://openapi.naver.com/v1/search/kin?query=" + query \
            + "&display="+ str(display) \
            + "&start="+ str(start_index) \
            + "&sort="+sort

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag,'',items[item_index]['description'])
            kin_df.loc[idx] = [title, link, description]
            write_sheet.append([idx,title,link,description])
            #work_sheet.cell(row = index +2, column=3).hyperlink = link['href']
            idx +=1
    else:
        print("Error Code:" + rescode)
kin_df
write_book.save('이유식_지식인.xlsx')
write_book.close()
# Out:
# 검색 질의: 이유식
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-66106a81d17f> in <module>
#      50             kin_df.loc[idx] = [title, link, description]
#      51             write_sheet.append([idx,title,link,description])
# ---> 52             work_sheet.cell(row = index +2, column=3).hyperlink = link['href']
#      53             idx +=1
#      54     else:
#
# TypeError: string indices must be integers

# %% [markdown]
# # 네이버 블로그 검색

# %%
import os
import sys
import urllib.request
import pandas as pd 
import json 
import re
import openpyxl 

write_book = openpyxl.Workbook()
write_sheet = write_book.active 
write_sheet.append(['인덱스','Title','Link','Description','Blogger Name','Blogger Link'])
write_sheet.column_dimensions['B'].width = 50
write_sheet.column_dimensions['C'].width = 70
write_sheet.column_dimensions['D'].width = 70
write_sheet.column_dimensions['E'].width = 70



client_id = "9DdQYYWtoOpgrw1YWAYZ"
client_secret = "dq175srVEK"

query = urllib.parse.quote(input('검색 질의: '))
idx = 0 #몇개를 받아오는지 셀 수 있는 인덱스 변수 설정
display = 100
start = 1 
end = 1000
sort = 'sim'

#저장을 판다스에 저장해보자 
#blog_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start,end,display):
    

    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
            + "&display="+ str(display) \
            + "&start="+ str(start_index) \
            + "&sort="+sort

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag,'',items[item_index]['description'])
            blogger_name = items[item_index]['bloggername']
            blogger_link = items[item_index]['bloggerlink']
            #blog_df.loc[idx] = [title, link, description]
            write_sheet.append([idx,title,link,description,blogger_name,blogger_link])
            
            idx +=1
    else:
        print("Error Code:" + rescode)
#blog_df
write_book.save('이유식_블로그.xlsx')
write_book.close()
# Out:
# 검색 질의: 이유식

# %% [markdown]
# # 네이버 쇼핑 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd 
import json 
import re
import openpyxl 

write_book = openpyxl.Workbook()
write_sheet = write_book.active 
write_sheet.append(['인덱스','Title','Link','Image','Low Price','High Price','Mall Name','Product ID','Product Type','Maker','Brand','category1','category2','category3','category4'])
write_sheet.column_dimensions['B'].width = 50
write_sheet.column_dimensions['C'].width = 70
write_sheet.column_dimensions['D'].width = 70
write_sheet.column_dimensions['G'].width = 70
write_sheet.column_dimensions['G'].width = 70



client_id = "9DdQYYWtoOpgrw1YWAYZ"
client_secret = "dq175srVEK"

query = urllib.parse.quote(input('검색 질의: '))
idx = 0 #몇개를 받아오는지 셀 수 있는 인덱스 변수 설정
display = 100
start = 1 
end = 1000
sort = 'sim'

#저장을 판다스에 저장해보자 
#blog_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start,end,display):
    

    url = "https://openapi.naver.com/v1/search/shop?query=" + query \
            + "&display="+ str(display) \
            + "&start="+ str(start_index) \
            + "&sort="+sort

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']
            low_price = items[item_index]['lprice']
            high_price = items[item_index]['hprice']
            mall_name = items[item_index]['mallName']
            product_id = items[item_index]['productId']
            product_type = items[item_index]['productType']
            maker = items[item_index]['maker']
            brand = items[item_index]['brand']
            category1 = items[item_index]['category1']
            category2 = items[item_index]['category2']
            category3 = items[item_index]['category3']
            category4 = items[item_index]['category4']
            
            #blog_df.loc[idx] = [title, link, description]
            write_sheet.append([idx,title,link,image,low_price,high_price,mall_name,product_id,product_type,maker,brand,category1,category2,category3,category4])
            idx +=1
    else:
        print("Error Code:" + rescode)
#blog_df
write_book.save('이유식_쇼핑.xlsx')
write_book.close()
# Out:
# 검색 질의: 이유식
