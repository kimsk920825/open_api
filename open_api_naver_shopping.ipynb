# %% [markdown]
# ## Open API(Rest API)를 활용한 크롤링
#
# ### Open API(Rest API)란?
#  - **API:** Application Programming Interface의 약자로, 특정 프로그램을 만들기 위해 제공되는 모듈(함수 등)을 의미
#  - **Open API:** 공개 API라고도 불리우며, 누구나 사용할 수 있도록 공개된 API (주로 Rest API 기술을 많이 사용함)
#  - **Rest API:** Representational State Transfer API의 약자로, HTTP프로토콜을 통해 서버 제공 기능을 사용할 수 있는 함수를 의미
#    - 일반적으로 XML, JSON의 형태로 응답을 전달(원하는 데이터 추출이 수월)
#    - [참고 - RestAPI란](http://hyunalee.tistory.com/1)

# %% [markdown]
# ### JSON 이란?
#  - JavaScript Object Notation 줄임말
#  - 웹환경에서 서버와 클라이언트 사이에 데이터를 주고 받을때 많이 사용
#    - Rest API가 주요한 예제
#  - JSON 포멧 예 <br>
#  { "id":"01", "language": "Java", "edition": "third", "author": "Herbert Schildt" }
#  <br>
#  <br>
#
#  - 참고 (https://books.google.co.kr/books?id=euSiAwAAQBAJ&pg=PT1755&lpg=PT1755&dq=json+%EC%9E%A5%EC%A0%90&source=bl&ots=VjTIoOjbTK&sig=3t7MXA7g2CvEi8SyD0-GQVywzw0&hl=ko&sa=X&ved=0ahUKEwiwo8OvxJfWAhXDsJQKHYaBDpI4ChDoAQhVMAg#v=onepage&q=json%20%EC%9E%A5%EC%A0%90&f=false)
#
#  출처: http://dpug.tistory.com/67#.WbycWshJaUk [퍼그의 전초기지]

# %%
import json

# 네이버 쇼핑에서, android 라는 키워드로 검색한 상품 리스트 결과
data = """
{
    "lastBuildDate": "Sun, 20 Dec 2020 05:54:29 +0900",
    "total": 1167666,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "[엠기어스] 엠스틱 MG-S01 16GB 차량용 멀티미디어 스트리밍 <b>안드로이드</b> 카스틱",
            "link": "https://search.shopping.naver.com/gate.nhn?id=82509622160",
            "image": "https://shopping-phinf.pstatic.net/main_8250962/82509622160.jpg",
            "lprice": "149000",
            "hprice": "0",
            "mallName": "엠기어스",
            "productId": "82509622160",
            "productType": "2",
            "brand": "엠기어스",
            "maker": "토마토",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        },
        {
            "title": "팅크웨어 아이나비 M500",
            "link": "https://search.shopping.naver.com/gate.nhn?id=15140462505",
            "image": "https://shopping-phinf.pstatic.net/main_1514046/15140462505.20200526160900.jpg",
            "lprice": "242190",
            "hprice": "535880",
            "mallName": "네이버",
            "productId": "15140462505",
            "productType": "1",
            "brand": "아이나비",
            "maker": "팅크웨어",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        },
        {
            "title": "범용 <b>안드로이드</b> 올인원 네비게이션 PX6 익스트림 에디션 유니버셜 7인치 / 10인치",
            "link": "https://search.shopping.naver.com/gate.nhn?id=82113730741",
            "image": "https://shopping-phinf.pstatic.net/main_8211373/82113730741.jpg",
            "lprice": "399000",
            "hprice": "0",
            "mallName": "모터스밸류",
            "productId": "82113730741",
            "productType": "2",
            "brand": "",
            "maker": "",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        },
        {
            "title": "[엠기어스] 엠스틱 MG-S01 16GB 차량용 멀티미디어 스트리밍 <b>안드로이드</b> 카스틱",
            "link": "https://search.shopping.naver.com/gate.nhn?id=24716965334",
            "image": "https://shopping-phinf.pstatic.net/main_2471696/24716965334.jpg",
            "lprice": "149000",
            "hprice": "0",
            "mallName": "쿠팡",
            "productId": "24716965334",
            "productType": "2",
            "brand": "엠기어스",
            "maker": "",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        },
        {
            "title": "USB 무선 카플레이 아이폰 무선 <b>안드로이드</b>오토 애플 네비게이션 미러링",
            "link": "https://search.shopping.naver.com/gate.nhn?id=22988715770",
            "image": "https://shopping-phinf.pstatic.net/main_2298871/22988715770.jpg",
            "lprice": "76000",
            "hprice": "0",
            "mallName": "쿠팡",
            "productId": "22988715770",
            "productType": "2",
            "brand": "",
            "maker": "",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        },
        {
            "title": "[유로이드] 차량용 <b>안드로이드</b> 시스템 32gb",
            "link": "https://search.shopping.naver.com/gate.nhn?id=82613656628",
            "image": "https://shopping-phinf.pstatic.net/main_8261365/82613656628.jpg",
            "lprice": "270000",
            "hprice": "0",
            "mallName": "CAR4PLAY",
            "productId": "82613656628",
            "productType": "2",
            "brand": "",
            "maker": "",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        },
        {
            "title": "팅크웨어 아이나비 LS300",
            "link": "https://search.shopping.naver.com/gate.nhn?id=11005176420",
            "image": "https://shopping-phinf.pstatic.net/main_1100517/11005176420.20190226162441.jpg",
            "lprice": "158850",
            "hprice": "299000",
            "mallName": "네이버",
            "productId": "11005176420",
            "productType": "1",
            "brand": "아이나비",
            "maker": "팅크웨어",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        },
        {
            "title": "순정화면에 리얼<b>안드로이드</b>9.0 구글플레이 SMART A200 무료장착 분할화면 간단한설치 <b>안드로이드</b>오토",
            "link": "https://search.shopping.naver.com/gate.nhn?id=24648719598",
            "image": "https://shopping-phinf.pstatic.net/main_2464871/24648719598.jpg",
            "lprice": "550000",
            "hprice": "0",
            "mallName": "쿠팡",
            "productId": "24648719598",
            "productType": "2",
            "brand": "",
            "maker": "",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        },
        {
            "title": "파인디지털 파인드라이브 T",
            "link": "https://search.shopping.naver.com/gate.nhn?id=19551877065",
            "image": "https://shopping-phinf.pstatic.net/main_1955187/19551877065.20191011170126.jpg",
            "lprice": "189000",
            "hprice": "259000",
            "mallName": "네이버",
            "productId": "19551877065",
            "productType": "1",
            "brand": "파인드라이브",
            "maker": "파인디지털",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        },
        {
            "title": "파인드라이브 몬스터8",
            "link": "https://search.shopping.naver.com/gate.nhn?id=16351737012",
            "image": "https://shopping-phinf.pstatic.net/main_1635173/16351737012.20181128100210.jpg",
            "lprice": "258490",
            "hprice": "520000",
            "mallName": "네이버",
            "productId": "16351737012",
            "productType": "1",
            "brand": "파인드라이브",
            "maker": "",
            "category1": "디지털/가전",
            "category2": "자동차기기",
            "category3": "내비게이션/액세서리",
            "category4": "내비게이션"
        }
    ]
}
"""
json_data = json.loads(data)
#json_data["items"][9]["title"]

for i in range(10):
    print(json_data["items"][i]["title"].strip())
    print(json_data["items"][i]["link"].strip())
# Out:
# [엠기어스] 엠스틱 MG-S01 16GB 차량용 멀티미디어 스트리밍 <b>안드로이드</b> 카스틱
# https://search.shopping.naver.com/gate.nhn?id=82509622160
# 팅크웨어 아이나비 M500
# https://search.shopping.naver.com/gate.nhn?id=15140462505
# 범용 <b>안드로이드</b> 올인원 네비게이션 PX6 익스트림 에디션 유니버셜 7인치 / 10인치
# https://search.shopping.naver.com/gate.nhn?id=82113730741
# [엠기어스] 엠스틱 MG-S01 16GB 차량용 멀티미디어 스트리밍 <b>안드로이드</b> 카스틱
# https://search.shopping.naver.com/gate.nhn?id=24716965334
# USB 무선 카플레이 아이폰 무선 <b>안드로이드</b>오토 애플 네비게이션 미러링
# https://search.shopping.naver.com/gate.nhn?id=22988715770
# [유로이드] 차량용 <b>안드로이드</b> 시스템 32gb
# https://search.shopping.naver.com/gate.nhn?id=82613656628
# 팅크웨어 아이나비 LS300
# https://search.shopping.naver.com/gate.nhn?id=11005176420
# 순정화면에 리얼<b>안드로이드</b>9.0 구글플레이 SMART A200 무료장착 분할화면 간단한설치 <b>안드로이드</b>오토
# https://search.shopping.naver.com/gate.nhn?id=24648719598
# 파인디지털 파인드라이브 T
# https://search.shopping.naver.com/gate.nhn?id=19551877065
# 파인드라이브 몬스터8
# https://search.shopping.naver.com/gate.nhn?id=16351737012

# %%
#step1
import requests
import pprint
client_id = '9DdQYYWtoOpgrw1YWAYZ'
client_secret = 'dq175srVEK'


naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=간장'
header_params = {"X-Naver-Client-id":client_id, "X-Naver-Client-Secret":client_secret}

res = requests.get(naver_open_api, headers = header_params)

if res.status_code ==200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index+1, item["title"],item["link"])

else:
    print("Error Code", res.status_code)
# Out:
# 1 홍게맛장소스 1.8L / 사은행사 / 홍게<b>간장</b> / 액젓 / 골드 https://search.shopping.naver.com/gate.nhn?id=9279245527
# 2 지리산산골 3년숙성 효모가살아있는 시골집 재래식 전통 조선<b>간장</b> 다솜국<b>간장</b> 1800ml https://search.shopping.naver.com/gate.nhn?id=8193491647
# 3 방송제품 라미란 영덕홍게<b>간장</b>골드 1.8L 프리미엄 홍게맛장소스 어<b>간장</b> 선물세트 만능소스 https://search.shopping.naver.com/gate.nhn?id=82200039360
# 4 코스트코 백종원의 만능장아찌 <b>간장</b>소스 장아찌 1.8Lx2 https://search.shopping.naver.com/gate.nhn?id=23001873739
# 5 샘표 샘표 양조<b>간장</b> 501 1.8L x 2개 https://search.shopping.naver.com/gate.nhn?id=24142826931
# 6 (만능 맛<b>간장</b>) 홍게맛장소스/어<b>간장</b>/다오네 장아찌 원액 https://search.shopping.naver.com/gate.nhn?id=11131386426
# 7 꼬마<b>간장</b> 일회용 https://search.shopping.naver.com/gate.nhn?id=10819856069
# 8 맛미 미니<b>간장</b> 6gX200입 일회용 조미<b>간장</b> 태산종합상사 https://search.shopping.naver.com/gate.nhn?id=19135546302
# 9 샘표 국산콩 <b>간장</b> 930ml https://search.shopping.naver.com/gate.nhn?id=23551225493
# ...

# %%
#step2
import requests
#import openpyxl

client_id = '9DdQYYWtoOpgrw1YWAYZ'
client_secret = 'dq175srVEK'
start, num = 1, 0

# excel_file = openpyxl.Workbook()
# excel_sheet = excel_file.active
# excel_sheet.column_dimensions['B'].width = 100
# excel_sheet.column_dimensions['C'].width = 100
# excel_sheet.append(['랭킹', '제목', '링크'])

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=간장&display=100&start=' + str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    if res.status_code == 200:
        data = res.json()
        for item in (data['items']):
            num += 1
            print(num, item['title'], item['link'])
    else:
        print ("Error Code:", res.status_code)
# Out:
# 1 홍게맛장소스 1.8L / 사은행사 / 홍게<b>간장</b> / 액젓 / 골드 https://search.shopping.naver.com/gate.nhn?id=9279245527
# 2 지리산산골 3년숙성 효모가살아있는 시골집 재래식 전통 조선<b>간장</b> 다솜국<b>간장</b> 1800ml https://search.shopping.naver.com/gate.nhn?id=8193491647
# 3 방송제품 라미란 영덕홍게<b>간장</b>골드 1.8L 프리미엄 홍게맛장소스 어<b>간장</b> 선물세트 만능소스 https://search.shopping.naver.com/gate.nhn?id=82200039360
# 4 코스트코 백종원의 만능장아찌 <b>간장</b>소스 장아찌 1.8Lx2 https://search.shopping.naver.com/gate.nhn?id=23001873739
# 5 샘표 샘표 양조<b>간장</b> 501 1.8L x 2개 https://search.shopping.naver.com/gate.nhn?id=24142826931
# 6 (만능 맛<b>간장</b>) 홍게맛장소스/어<b>간장</b>/다오네 장아찌 원액 https://search.shopping.naver.com/gate.nhn?id=11131386426
# 7 꼬마<b>간장</b> 일회용 https://search.shopping.naver.com/gate.nhn?id=10819856069
# 8 맛미 미니<b>간장</b> 6gX200입 일회용 조미<b>간장</b> 태산종합상사 https://search.shopping.naver.com/gate.nhn?id=19135546302
# 9 샘표 국산콩 <b>간장</b> 930ml https://search.shopping.naver.com/gate.nhn?id=23551225493
# ...
